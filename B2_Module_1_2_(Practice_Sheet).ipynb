# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhaiminulJamee/Ostad-AI-Engineering-Batch-2/blob/main/B2_Module_1_2_(Practice_Sheet).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 AI Engineer Bootcamp - Class 2
#
# ## 🧪 Module 1: Types of Machine Learning + Importance of Data

# %% [markdown]
# ## 🔍 Types of Machine Learning
#
# ### ✅ Supervised Learning
# ![Supervised-learning.png](data:image/png;base64,...)
# - **Definition:** Trained on labeled data (input + known output).
# - **Common Use Cases:**
#   - Spam detection (Email = spam/not spam)
#   - Credit risk prediction
#   - Image classification (cat vs dog)
#   - House price prediction

# %% [markdown]
# ![block-diagram-of-dog-vs-cat.webp](data:image/webp;base64,...)

# %%
# Data -> Train Validation Test  ( 100)-> (70 20 10) ( 80 10 10)

# %% [markdown]
# ## ✅ Supervised Learning – Titanic Dataset

# %%
# Load dataset
import pandas as pd

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
len(df.columns)
# Out:
# 12

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ## 🔎 Step 1: Understand the Dataset

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Show columns
print("Columns in dataset:")
print(df.columns.tolist())
# Out:
# Columns in dataset:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# Check for missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# ##  Step 2: Basic EDA (Exploratory Data Analysis)

# %%
#Pandas df  , matplotlib Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot class distribution
sns.countplot(x='Survived', data=df)
plt.title("Survival Distribution")
plt.show()

# %%
# Sex vs Survived
sns.countplot(x='Sex', hue='Survived', data=df)
plt.title("Sex vs Survival")
plt.show()

# %% [markdown]
# ## 🧭 What’s Next
#
# ### 🛠 Next Steps for Supervised Learning
# - Handle missing values (Age, Cabin, Embarked)
# - Encode categorical variables (Sex, Embarked)
# - Feature Engineering (e.g., Family Size, Title from Name)
# - Train/Test Split
# - Train a classifier (e.g., Logistic Regression)
# - Evaluate using accuracy, precision, recall

# %% [markdown]
# #### 📌 Popular Supervised Algorithms:
# - Linear Regression
# - Logistic Regression
# - Decision Trees
# - Random Forest
# - Naive Bayes
# - k-Nearest Neighbors (KNN)

# %% [markdown]
# ### ❓ Unsupervised Learning
# ![Unsupervised-learning.png](data:image/png;base64,...)
# - **Definition:** Trained on data without labels, finding hidden patterns.
# - **Common Use Cases:**
#   - Customer segmentation
#   - Market basket analysis
#   - Anomaly detection

# %% [markdown]
# #### 📌 Popular Unsupervised Algorithms:
# - K-Means Clustering
# - DBSCAN
# - Hierarchical Clustering

# %% [markdown]
# ![1_yrkvweErbifbPFkBUyZlOw.png](data:image/png;base64,...)

# %% [markdown]
# ## 📈 Real-World Impact of ML Applications
# - Personalized recommendations (YouTube, Netflix)
# - Fraud detection in banking
# - Disease diagnosis from images
# - Customer behavior prediction

# %% [markdown]
# ![FDS-image.png](data:image/png;base64,...)

# %% [markdown]
# ![c_customer_segmentation_python_practical_approach_1.png](data:image/png;base64,...)

# %% [markdown]
# ## 🧭 When to Use Supervised vs. Unsupervised?
# - **Supervised:** When labeled data is available and you know what to predict/classify.
# - **Unsupervised:** When the goal is to discover hidden structure or patterns.

# %% [markdown]
# ## 🌌 Unsupervised Learning – No Labels Example (Titanic)

# %%
# Drop label column to simulate "no labels" scenario
df_unsupervised = df.drop(columns=['Survived'])
df_unsupervised.head()
# Out:
#    PassengerId  Pclass                                               Name  \
# 0            1       3                            Braund, Mr. Owen Harris
# 1            2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2            3       3                             Heikkinen, Miss. Laina
# 3            4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            5       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
df_unsupervised.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ### 🧭 What’s Next for Unsupervised Learning
# ### 🧩 Next Steps for Unsupervised Learning
# - Normalize/scale numeric features
# - Handle missing data
# - Choose an algorithm (e.g., K-Means, DBSCAN, PCA)
# - Set number of clusters (if needed)
# - Visualize clusters
# - Analyze what each cluster represents

# %% [markdown]
# ## 📥 How to Collect Data
# - Open datasets (Kaggle, UCI)
# - Web scraping
# - APIs (Twitter, Reddit, etc.)
# - User forms/surveys
# - Internal company databases

# %% [markdown]
# ## 📊 What is EDA (Exploratory Data Analysis)?
# ![What-is-EDA_.webp](data:image/webp;base64,...)
# - A process to understand the data before modeling
# - Identify missing values, distributions, correlations
# - Visualize data trends
# - Clean and preprocess the data

# %% [markdown]
# ## 🔑 Why Data is More Important than Algorithms
# ![image.png](data:image/png;base64,...)
# - Even powerful models fail with poor data
# - Quality and quantity of data drive performance
# - Garbage in → Garbage out

# %% [markdown]
# ## 🌀 Real Data is Messy
# - Model may fail on real-world unseen data
# - Need to collect more, clean, and re-train
# - Add more features or fix issues

# %% [markdown]
# ## ♻️ ML is an Iterative Process
# - It's NOT one time training and done
# - You:
#   1. Train
#   2. Test
#   3. Observe
#   4. Improve
#   5. Repeat
#
# ### 🧠 Model improvement happens with:
# - Better data
# - Feature engineering
# - More training examples
# - Feedback loops

# %% [markdown]
# 🎯 **Key Takeaway:**
# > "Machine Learning is not just about algorithms — it's about understanding your data, choosing the right tools, and constantly improving your system."
